# %% [markdown]
# # Simple Rename Fixture
#
# Tiny notebook used by Tier 1 stress-test tasks. Cell 3 contains an intentional syntax error.

# %%
import pandas as pd
import numpy as np

rng = np.random.default_rng(42)
df_north = pd.DataFrame({
    'day': pd.date_range('2024-01-01', periods=10, freq='D'),
    'sales': rng.integers(50, 200, size=10),
})
df_north.head()

# %% [markdown]
# ## Section 1 — Summary stats

# %%
# NOTE: this cell has a syntax error — missing closing paren
total = df_north['sales'].sum(
print('total sales =', total)

# %%
mean_sales = df_north['sales'].mean()
print('mean sales =', mean_sales)
